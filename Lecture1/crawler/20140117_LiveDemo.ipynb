# %%
import urllib2

# %%
res = urllib2.urlopen("http://tw.stock.yahoo.com/d/s/major_2451.html")

# %%
res
# Out:
# <addinfourl at 46307376 whose fp = <socket._fileobject object at 0x2952450>>

# %%
res_ = res.read()

# %%
res_
# Out:
# '<!doctype html public "-//w3c//dtd html 4.01//en" "http://www.w3.org/tr/html4/strict.dtd">\n<html>\n<head>\n<meta http-equiv="Content-Type" content="text/html; charset=big5">\n<meta http-equiv="Expires" content="Fri, 10 Jul 1998 15:00:00 +0800">\n<meta http-equiv="Cache-Control" content="no-cache">\n<meta name="application-name" content="Yahoo!\\xa9_\\xbc\\xaf\\xaa\\xd1\\xa5\\xab"/>\n<meta name="msapplication-TileColor" content="#7b0099"/> \n<meta name="msapplication-TileImage" content="http://tw.yimg.com/i/tw/stock/tw_stock_icon_pin.png"/>\n<meta name="description" content="\xb3\xd0\xa8\xa3(2451)\xad\xd3\xaa\xd1\xb7\xed\xa4\xe9\xa5D\xa4O\xb6i\xa5X\xa1A\xacd\xb8\xdf \xb3\xd0\xa8\xa3 \xad\xd3\xaa\xd1\xaa\xd1\xbb\xf9\xa1B\xb7s\xbbD\xa1B\xa6\xa8\xa5\xe6\xa9\xfa\xb2\xd3\xa1B\xa7\xde\xb3N\xa4\xc0\xaaR\xb5\xa5\xb8\xea\xb0T\xa1A\xb4N\xa6bYahoo!\xa9_\xbc\xaf\xaa\xd1\xa5\xab\xa1C">\n<TITLE>\xb3\xd0\xa8\xa3(2451)-\xa5D\xa4O\xb6i\xa5X-\xa9_\xbc\xaf\xaa\xd1\xa5\xab</TITLE><!--------------------
# ...

# %%
import pandas as pd

# %%
tables = pd.read_html(res_)

# %%
tables[3]
# Out:
#         0    1   2    3      4   5   6   7
# 0    買超券商  NaN NaN  NaN   賣超券商 NaN NaN NaN
# 1   台灣東方匯  224   0  224   凱基證券   1  62 -61
# 2    花旗環球  103   0  103   元大寶來  23  54 -31
# 3   新加坡商瑞   73  51   22  永豐金證券   0  30 -30
# 4    瑞士信貸   18   0   18   群益金鼎   0  28 -28
# 5      亞東   10   3    7   華南永昌   2  29 -27
# 6   台灣摩根士    6   3    3   國票證券   5  27 -22
# 7      土銀    0   0    0   玉山證券   3  22 -19
# 8    港商野村    0   0    0     統一   1  17 -16
# 9      永興    0   0    0   日盛證券   0  13 -13
# 10   福邦證券    0   0    0   富邦證券   7  19 -12
# 11     台安    0   0    0   摩根大通   0  11 -11
# 12     萬泰    0   0    0   兆豐證券   2  12 -10
# 13  台灣巴克萊    0   0    0  港商法國興   0   8  -8
# 14     彰銀    0   0    0   國泰證券   1   8  -7
# 15     日進    0   0    0   大慶證券   0   6  -6

# %%
pd.DataFrame(tables[3].values[1:,:])
# Out:
#         0    1   2    3      4   5   6   7
# 0   台灣東方匯  224   0  224   凱基證券   1  62 -61
# 1    花旗環球  103   0  103   元大寶來  23  54 -31
# 2   新加坡商瑞   73  51   22  永豐金證券   0  30 -30
# 3    瑞士信貸   18   0   18   群益金鼎   0  28 -28
# 4      亞東   10   3    7   華南永昌   2  29 -27
# 5   台灣摩根士    6   3    3   國票證券   5  27 -22
# 6      土銀    0   0    0   玉山證券   3  22 -19
# 7    港商野村    0   0    0     統一   1  17 -16
# 8      永興    0   0    0   日盛證券   0  13 -13
# 9    福邦證券    0   0    0   富邦證券   7  19 -12
# 10     台安    0   0    0   摩根大通   0  11 -11
# 11     萬泰    0   0    0   兆豐證券   2  12 -10
# 12  台灣巴克萊    0   0    0  港商法國興   0   8  -8
# 13     彰銀    0   0    0   國泰證券   1   8  -7
# 14     日進    0   0    0   大慶證券   0   6  -6
