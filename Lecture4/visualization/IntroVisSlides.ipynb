# %%
# %matplotlib inline

# %%
import matplotlib.pylab as pylab
pylab.rcParams['figure.figsize'] = 16, 12

# %% [markdown]
# Visualization With Python
# ==========================

# %% [markdown]
# Chia-Chi Chang
# --------------

# %% [markdown]
# # What is Visualization ?

# %% [markdown]
# # Visualizing What ?

# %% [markdown]
# # In this Lecture, we will introduce Visulization of ...
#
# -   ## Data
# -   ## Problems
# -   ## Models
# -   ## Concepts

# %% [markdown]
# # Visulization of Data ...

# %% [markdown]
# # Table-Style ...

# %%
from pandas.io.data import DataReader
TW2330_df = DataReader(name="2330.TW", data_source="yahoo")
TW2330_df.tail(15)
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 2014-01-22  106.0  107.5  106.0  107.5   28698000      107.5
# 2014-01-23  108.5  108.5  107.5  107.5   27910000      107.5
# 2014-01-24  107.0  108.5  107.0  108.0   33999000      108.0
# 2014-01-27  106.0  106.5  104.0  105.0   64827000      105.0
# 2014-01-28  105.0  105.0  105.0  105.0          0      105.0
# 2014-01-29  105.0  105.0  105.0  105.0          0      105.0
# 2014-01-30  105.0  105.0  105.0  105.0          0      105.0
# 2014-01-31  105.0  105.0  105.0  105.0          0      105.0
# 2014-02-03  105.0  105.0  105.0  105.0          0      105.0
# 2014-02-05  102.0  102.0  100.5  100.5  145517000      100.5
# 2014-02-06  101.0  103.0  101.0  102.0   71895000      102.0
# 2014-02-07  103.5  104.5  103.0  104.0   54104000      104.0
# 2014-02-10  104.0  104.5  103.0  103.0   26221000      103.0
# 2014-02-11  104.5  105.0  104.0  104.5   21030000      104.5
# ...

# %% [markdown]
# # Line-Style & Candlestick Chart-Style...

# %%
import datetime,time
TW2330_df_with_time = TW2330_df.reset_index()
TW2330_df_with_time["Date"] = TW2330_df_with_time["Date"].map(lambda xx:time.mktime(xx.timetuple()))


fig, axes = plt.subplots(nrows=1, ncols=2)
TW2330_df[["Open","High","Low","Close"]].tail(100).plot(ax=axes[0])

from matplotlib.finance import candlestick,candlestick2
candlestick(axes[1],TW2330_df_with_time[["Date","Open","High","Low","Close"]].tail(100).values,
            width=2,colorup="g",colordown="r")
print "Comparing Two Type Ploting"
# Out:
# Comparing Two Type Ploting

# %% [markdown]
# # What is Candlestick Chart?

# %% [markdown]
# ![](CandlestickBasicsChart.gif)

# %% [markdown]
# ## Ref:
#
# - ### [(Youtube Video) Candlestick Chart Sample Code (1m41s)](http://www.youtube.com/watch?v=eDk4JDDTRaM#t=1m41s)
# - ### [(Blog) How to Chart Stocks and Forex. Doing your own Financial Charting With Programming](http://sentdex.com/sentiment-analysisbig-data-and-python-tutorials-algorithmic-trading/how-to-chart-stocks-and-forex-doing-your-own-financial-charting/)
# - ### [(IPYNB) zipline](http://nbviewer.ipython.org/gist/twiecki/3962843)
# - ### [(StackoverFlow) df.plot with ax](http://stackoverflow.com/questions/14888473/python-pandas-dataframe-subplot-in-columns-and-rows)
# - ### [(Web) Candlestick Chart](http://www.onlinetradingconcepts.com/TechnicalAnalysis/Candlesticks/CandlestickBasics.html)

# %% [markdown]
# # Visulization of Problem ...

# %% [markdown]
# # How To remove noise ... ?

# %%
import numpy as np
from PIL import Image
import matplotlib.cm as cm
im = Image.open("coffee.jpg").convert('L')
im_array = pylab.array(im)
im_array = im_array[:-1,:]
print im_array.shape
im_array_n = im_array + 200*np.random.randn(*im_array.shape)

pylab.imshow(im_array_n,cmap=cm.gray)
# Out:
# (1264, 1536)

# %% [markdown]
# # Change the Point of View ...
#
# ![](COSCUP_R_Pic4.jpg)

# %% [markdown]
# # Watching the image (and problems) on the other Point of View ....

# %% [markdown]
# ![FFT Denoise](FFT_Demo.png)

# %% [markdown]
# ## Ref:
#
# - ### [(IPYNB) Gaussian Filter](http://nbviewer.ipython.org/github/c3h3/Computational-Methods-for-Data-Analysis/blob/master/GaussianFilter.ipynb)
# - ### [(Coursera Course)](https://class.coursera.org/compmethods-004)

# %% [markdown]
# # Model Visulization ...

# %% [markdown]
# # Comparison of (Clustering) Models:
#
# -   ## [sklearn - Clustering](http://scikit-learn.org/stable/auto_examples/cluster/plot_cluster_comparison.html#example-cluster-plot-cluster-comparison-py)

# %% [markdown]
# ![](plot_cluster_comparison_1.png)

# %% [markdown]
# # Visualizing PCA:

# %% [markdown]
# ![](pca_1.jpg)
# ![](pca_2.png)

# %% [markdown]
# ## Ref:
#
# -  ###[(ebook) Elements of Statistical Learning](http://statweb.stanford.edu/~tibs/ElemStatLearn/)
# -  ###[(Stanford Online MOOCs) Statistical Learning](http://online.stanford.edu/course/statistical-learning-winter-2014)

# %% [markdown]
# # Comparison of (Manifold Learning) Models:
#
# -  ## [sklearn - Manifold Learning](http://scikit-learn.org/stable/auto_examples/manifold/plot_lle_digits.html)

# %% [markdown]
# ![](plot_lle_digits_1.png)

# %% [markdown]
# ![](plot_lle_digits_2.png)
# ![](plot_lle_digits_3.png)
# ![](plot_lle_digits_4.png)
# ![](plot_lle_digits_5.png)
# ![](plot_lle_digits_6.png)
# ![](plot_lle_digits_7.png)
# ![](plot_lle_digits_8.png)
# ![](plot_lle_digits_9.png)

# %% [markdown]
# # Concepts Visulization ...

# %% [markdown]
# # Find the Linear Regression Model:

# %% [markdown]
# # If you have Data ...
#
# ![](demo_data.png)

# %% [markdown]
# # Which Models is the best ?
#
# ![](models_on_data.png)

# %% [markdown]
# # How to get the Best Model?
#
# ![](gradient_dec.png)

# %% [markdown]
# # Solving of Optimization Problems:

# %% [markdown]
# # Linear Programming:
#
# ## $$ \begin{eqnarray} \min_{x_1,x_2} x_1 & + & x_2 \\ 2x_1 & + & x_2 & \geq 1 \\ x_1 & + & 3x_2 & \geq 1 \\ x_1 &&& \geq 0 \\ x_2 &&& \geq 0 \\ \end{eqnarray}$$

# %% [markdown]
# ![](LP_Demo.png)

# %% [markdown]
# # Min-Max Problem:
#
# ## $$ \begin{eqnarray} \min_{x_1,x_2} \max( x_1 & , & x_2 ) \\ 2x_1 & + & x_2 & \geq 1 \\ x_1 & + & 3x_2 & \geq 1 \\ x_1 &&& \geq 0 \\ x_2 &&& \geq 0 \\ \end{eqnarray}$$

# %% [markdown]
# ![](MinMax_Demo.png)

# %% [markdown]
# # Quadratic Programming:
#
# ## $$ \begin{eqnarray} \min_{x_1,x_2}  x_1^2 & + & 9x_2^2  \\ 2x_1 & + & x_2 & \geq 1 \\ x_1 & + & 3x_2 & \geq 1 \\ x_1 &&& \geq 0 \\ x_2 &&& \geq 0 \\ \end{eqnarray}$$

# %% [markdown]
# ![](QP_Demo.png)

# %% [markdown]
# # Time-Frequency Analysis ...

# %% [markdown]
# ![](sliding_window_animation.gif)

# %% [markdown]
# # Spectrogram
#
# ![](Spectrogram.png)
